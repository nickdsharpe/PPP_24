# %%
import pandas as pd
import time
import numpy as np
np.seterr(invalid='ignore')
import nbimporter
from PPP import PPP
from defense_PPP import defense_PPP
from court import create_court
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import json
pd.options.display.max_columns = 999

# %%
file_path = 'Nuggets/data/Offense/Team.json'
defense_path = 'Nuggets/data/Defense/Team.json'

with open (file_path, 'r') as f:
    file = json.load(f)
    
with open (defense_path, 'r') as d:
    defense_file = json.load(d)
    
print(file.keys())
# Out:
# dict_keys(['ovr_data', 'SMZ2', '3ptZ2', 'Rim', 'SMZ3', '3ptZ1', '3ptZ3', 'SMZ1 ', '3ptZ4', 'LMZ3', '3ptZ5', 'LMZ1'])

# %%
data_PPP = file['ovr_data']['data']
data_PPP = pd.DataFrame(data_PPP).transpose()
data_PPP = PPP(data_PPP)
data_PPP
# Out:
#                     Total PPP % of Poss. Total TO Total Creation % Total FTR  \
# PNR Ball Handler          1.1       15.1        1             44.9      0.22
# PNR Screener             1.74        4.0        1              0.0       2.0
# DHO Ball Handler          2.0        2.8        0              0.0       0.0
# DHO Screener              2.0        1.4        0            100.0       0.0
# ISOLATION                0.93       20.8        3             26.7       0.0
# TRANSITION               0.79       19.4        0             50.0       0.0
# Attacking Closeouts      1.29        9.7        0             14.3       0.0
# Catch & Shoot             1.0       12.5        0              0.0       0.0
# Off Ball Screens         0.67        4.2        0              0.0       0.0
# Cutting                   2.0        6.9        0             20.0       0.0
# Off. Rebounds             2.0        5.6        0             25.0       0.0
# TOTAL                    1.17         72      6.9             26.4      0.06
#
#                     Total TS% Total SQ Total 2pt FGA Total 2pt FG%  \
# PNR Ball Handler        60.73     3.67             6          33.3
# PNR Screener           132.98      5.0             0           N/A
# DHO Ball Handler        100.0      3.5             2         100.0
# DHO Screener            100.0      3.0             1         100.0
# ISOLATION               58.33     3.17             7          57.1
# TRANSITION              39.29      4.0             5          80.0
# Attacking Closeouts     64.29     3.14             6          50.0
# Catch & Shoot            50.0     3.89             0           N/A
# Off Ball Screens        33.33     3.67             1         100.0
# Cutting                 100.0      4.2             5         100.0
# Off. Rebounds           100.0      4.0             4         100.0
# TOTAL                   62.54     3.69            37          70.3
#
#                     Total 2pt SQ Total 3pt FGA Total 3pt FG% Total 3pt SQ  \
# PNR Ball Handler            3.67             3          66.7         3.67
# PNR Screener                 N/A             1         100.0          5.0
# DHO Ball Handler             3.5             0           N/A          N/A
# DHO Screener                 3.0             0           N/A          N/A
# ISOLATION                    3.0             5          40.0          3.4
# TRANSITION                   4.6             9          11.1         3.67
# Attacking Closeouts         2.83             1         100.0          5.0
# Catch & Shoot                N/A             9          33.3         3.89
# Off Ball Screens             3.0             2           0.0          4.0
# Cutting                      4.2             0           N/A          N/A
# Off. Rebounds                4.0             0           N/A          N/A
# TOTAL                       3.59            30          33.3          3.8
#
#                     Shooting PPP % of Shooting Poss. Shooting TO  \
# PNR Ball Handler            0.83                11.3           1
# PNR Screener                1.74                 5.4           1
# DHO Ball Handler             2.0                 3.8           0
# DHO Screener                 N/A                 0.0           0
# ISOLATION                   0.82                20.8           3
# TRANSITION                  0.57                13.2           0
# Attacking Closeouts          1.0                11.3           0
# Catch & Shoot                1.0                17.0           0
# Off Ball Screens            0.67                 5.7           0
# Cutting                      2.0                 7.5           0
# Off. Rebounds                2.0                 5.7           0
# TOTAL                       1.08                  53        9.43
#
#                     Shooting Freq. Shooting FTR Shooting TS% Shooting SQ  \
# PNR Ball Handler              55.1          0.0         50.0         3.4
# PNR Screener                 100.0          2.0       132.98         5.0
# DHO Ball Handler             100.0          0.0        100.0         3.5
# DHO Screener                   0.0          0.0          N/A         N/A
# ISOLATION                     73.3          0.0        56.25        2.88
# TRANSITION                    50.0          0.0        28.57         4.0
# Attacking Closeouts           85.7          0.0         50.0        2.83
# Catch & Shoot                100.0          0.0         50.0        3.89
# Off Ball Screens             100.0          0.0        33.33        3.67
# Cutting                       80.0          0.0        100.0        4.25
# Off. Rebounds                 75.0          0.0        100.0        3.67
# TOTAL                         73.6         0.04       148.42        3.56
#
#                     Shooting 2pt Poss. Shooting 2pt FG% Shooting 2pt SQ  \
# PNR Ball Handler                     4             33.3            3.67
# PNR Screener                         1              N/A             N/A
# DHO Ball Handler                     2            100.0             3.5
# DHO Screener                         0              N/A             N/A
# ISOLATION                            8             50.0            2.67
# TRANSITION                           3             66.7            4.33
# Attacking Closeouts                  6             50.0            2.83
# Catch & Shoot                        0              N/A             N/A
# Off Ball Screens                     1            100.0             3.0
# Cutting                              4            100.0            4.25
# Off. Rebounds                        3            100.0            3.67
# TOTAL                               32             67.9            3.39
#
#                     Shooting 3pt Poss. Shooting 3pt FG% Shooting 3pt SQ  \
# PNR Ball Handler                     2             50.0             3.0
# PNR Screener                         1            100.0             5.0
# DHO Ball Handler                     0              N/A             N/A
# DHO Screener                         0              N/A             N/A
# ISOLATION                            3             50.0             3.5
# TRANSITION                           4              0.0            3.75
# Attacking Closeouts                  0              N/A             N/A
# Catch & Shoot                        9             33.3            3.89
# Off Ball Screens                     2              0.0             4.0
# Cutting                              0              N/A             N/A
# Off. Rebounds                        0              N/A             N/A
# TOTAL                               21             30.0             3.8
#
#                     Creation PPP % of Creation Poss. Creation TO Creation %  \
# PNR Ball Handler            1.43                25.7           0       44.9
# PNR Screener                 N/A                 0.0           0        0.0
# DHO Ball Handler             N/A                 0.0           0        0.0
# DHO Screener                 2.0                 5.3           0      100.0
# ISOLATION                   1.25                21.1           0       26.7
# TRANSITION                   1.0                36.8           0       50.0
# Attacking Closeouts          3.0                 5.3           0       14.3
# Catch & Shoot                N/A                 0.0           0        0.0
# Off Ball Screens             N/A                 0.0           0        0.0
# Cutting                      2.0                 5.3           0       20.0
# Off. Rebounds                2.0                 5.3           0       25.0
# TOTAL                       1.41                  19         0.0       26.4
#
#                     Creation FTR Creation TS% Creation SQ Creation 2pt Poss.  \
# PNR Ball Handler             0.5        71.72         4.0                  3
# PNR Screener                 0.0          N/A         N/A                  0
# DHO Ball Handler             0.0          N/A         N/A                  0
# DHO Screener                 0.0        100.0         3.0                  1
# ISOLATION                    0.0         62.5        3.75                  1
# TRANSITION                   0.0         50.0         4.0                  2
# Attacking Closeouts          0.0        150.0         5.0                  0
# Catch & Shoot                0.0          N/A         N/A                  0
# Off Ball Screens             0.0          N/A         N/A                  0
# Cutting                      0.0        100.0         4.0                  1
# Off. Rebounds                0.0        100.0         5.0                  1
# TOTAL                       0.11       161.68         4.0                  9
#
#                     Creation 2pt FG% Creation 2pt SQ Creation 3pt Poss.  \
# PNR Ball Handler                33.3            3.67                  1
# PNR Screener                     N/A             N/A                  0
# DHO Ball Handler                 N/A             N/A                  0
# DHO Screener                   100.0             3.0                  0
# ISOLATION                      100.0             5.0                  3
# TRANSITION                     100.0             5.0                  5
# Attacking Closeouts              N/A             N/A                  1
# Catch & Shoot                    N/A             N/A                  0
# Off Ball Screens                 N/A             N/A                  0
# Cutting                        100.0             4.0                  0
# Off. Rebounds                  100.0             5.0                  0
# TOTAL                           77.8            4.22                 10
#
#                     Creation 3pt FG% Creation 3pt SQ
# PNR Ball Handler               100.0             3.0
# PNR Screener                     N/A             5.0
# DHO Ball Handler                 N/A             N/A
# DHO Screener                     N/A             N/A
# ISOLATION                       33.3             3.5
# TRANSITION                      20.0            3.75
# Attacking Closeouts            100.0             N/A
# Catch & Shoot                    N/A            3.89
# Off Ball Screens                 N/A             4.0
# Cutting                          N/A             N/A
# Off. Rebounds                    N/A             N/A
# TOTAL                           40.0             3.8

# %%
shots = file['ovr_data']['created_locations']

# General plot parameters
mpl.rcParams['font.family'] = 'Avenir'
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.linewidth'] = 2
# Draw basketball court
fig = plt.figure(figsize=(6, 5.64))
ax = fig.add_axes([0, 0, 1, 1])
ax = create_court(ax, 'black')

for shot in shots:
    x = shot[0][0]
    y = shot[0][1] + 60
    res = shot[1]
    if res == 1:
        ax.plot(x,y, marker='o', color='#29c42e', markersize=9)
    if res == 0:
        ax.plot(x,y, marker='x', color='red', markersize=10)
    if res == 11: # Free Throws
        ax.plot(x,y, marker='^', color='#2393de', markersize=10)
    if res == 20: # Turnovers
        ax.plot(x,y, marker='D', color='#f5c133', markersize=8)
    if res == 30: # And-1
        ax.plot(x,y, marker='P', color='#e00ddd', markersize=10)
        
plt.show()

# %%
def_PPP = defense_file['ovr_data']['data']
def_PPP = pd.DataFrame(def_PPP).transpose()
def_PPP = defense_PPP(def_PPP)
def_PPP
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16900\3726418910.py in <module>
#       1 def_PPP = defense_file['ovr_data']['data']
#       2 def_PPP = pd.DataFrame(def_PPP).transpose()
# ----> 3 def_PPP = defense_PPP(def_PPP)
#       4 def_PPP
#
# ~\OneDrive\Desktop\NBA\NBA_PPP_23_24\defense_PPP.py in defense_PPP(data)
#     267     for i, col_dict in col_dicts.items():
#     268
# --> 269         shoot2FGA = col_dict['shoot2FGA']
#     270         shoot2FGM = col_dict['shoot2FGM']
#     271         shoot2FTA = col_dict['shoot2FTA']
#
# KeyError: 'shoot2FGA'
