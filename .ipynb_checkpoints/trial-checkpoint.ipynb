# %%
import pandas as pd
import time
import numpy as np
np.seterr(invalid='ignore')
import nbimporter
from PPP import PPP
from defense_PPP import defense_PPP
from court import create_court
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import json
import plotly.graph_objects as go
import plotly.offline as pyo
pd.options.display.max_columns = 999

# %%
file_path = 'Nuggets/data/Offense/Team.json'
defense_path = 'Nuggets/data/Defense/Team.json'

with open (file_path, 'r') as f:
    file = json.load(f)
    
with open (defense_path, 'r') as d:
    defense_file = json.load(d)
    
print(file.keys())
# Out:
# dict_keys(['ovr_data', 'SMZ2', '3ptZ2', 'Rim', 'SMZ3', '3ptZ1', '3ptZ3', 'SMZ1 ', '3ptZ4', 'LMZ3', '3ptZ5', 'LMZ1', 'LMZ2'])

# %%
data_PPP = file['ovr_data']['data']
data_PPP = pd.DataFrame(data_PPP).transpose()
data_PPP = PPP(data_PPP)
data_PPP
# Out:
#                     Total PPP % of Poss. Total TO Total Creation % Total FTR  \
# PNR Ball Handler         1.17       15.9        2             43.7      0.17
# PNR Screener              1.5        5.5        2              0.0      0.75
# DHO Ball Handler         1.67        4.5        0             16.7       0.0
# DHO Screener              2.0        0.7        0            100.0       0.0
# ISOLATION                1.08       23.5        5             26.4      0.35
# TRANSITION               0.85       18.5        2             43.9      0.19
# Attacking Closeouts      1.44        7.8        0             19.2       0.1
# Catch & Shoot            1.07       10.4        0              0.0       0.0
# Off Ball Screens          1.0        3.0        0             25.0       0.0
# Cutting                  1.72        7.4        1             10.1      0.25
# Off. Rebounds             2.0        3.7        0             20.0       0.0
# TOTAL                    1.21        134      9.0             26.1      0.18
#
#                     Total TS% Total SQ Total 2pt FGA Total 2pt FG%  \
# PNR Ball Handler        66.21      3.5            13          53.8
# PNR Screener            112.7      3.0             3         100.0
# DHO Ball Handler        83.33      3.5             5         100.0
# DHO Screener            100.0      3.0             1         100.0
# ISOLATION               71.19     2.74            16          62.5
# TRANSITION              47.99     3.67            11          72.7
# Attacking Closeouts      75.0      3.0             9          66.7
# Catch & Shoot           53.57     3.93             0           N/A
# Off Ball Screens         50.0      4.0             2         100.0
# Cutting                100.71     3.88             8         100.0
# Off. Rebounds           100.0      4.2             5         100.0
# TOTAL                   69.52     3.44            73          75.3
#
#                     Total 2pt SQ Total 3pt FGA Total 3pt FG% Total 3pt SQ  \
# PNR Ball Handler            3.31             5          60.0          4.0
# PNR Screener                2.33             1         100.0          5.0
# DHO Ball Handler             3.4             1           0.0          4.0
# DHO Screener                 3.0             0           N/A          N/A
# ISOLATION                   2.31             7          57.1         3.71
# TRANSITION                  3.55            10          10.0          3.8
# Attacking Closeouts         2.78             1         100.0          5.0
# Catch & Shoot                N/A            14          35.7         3.93
# Off Ball Screens             4.0             2           0.0          4.0
# Cutting                     3.88             0           N/A          N/A
# Off. Rebounds                4.2             0           N/A          N/A
# TOTAL                       3.16            41          36.6         3.93
#
#                     Shooting PPP % of Shooting Poss. Shooting TO  \
# PNR Ball Handler            0.83                12.1           2
# PNR Screener                 1.5                 7.4           2
# DHO Ball Handler             1.6                 5.1           0
# DHO Screener                 N/A                 0.0           0
# ISOLATION                   0.86                23.4           5
# TRANSITION                  0.65                14.0           2
# Attacking Closeouts         1.18                 8.5           0
# Catch & Shoot               1.07                14.1           0
# Off Ball Screens            0.67                 3.0           0
# Cutting                     1.69                 9.0           1
# Off. Rebounds                2.0                 4.0           0
# TOTAL                       1.08                  99       12.12
#
#                     Shooting Freq. Shooting FTR Shooting TS% Shooting SQ  \
# PNR Ball Handler              56.3          0.0         50.0         3.5
# PNR Screener                 100.0         0.75        112.7         3.0
# DHO Ball Handler              83.3          0.0         80.0         3.8
# DHO Screener                   0.0          0.0          N/A         N/A
# ISOLATION                     73.6         0.31        60.83        2.44
# TRANSITION                    56.1         0.18        39.34        3.36
# Attacking Closeouts           80.8         0.12         62.5        2.75
# Catch & Shoot                100.0          0.0        53.57        3.93
# Off Ball Screens              75.0          0.0        33.33        3.67
# Cutting                       89.9         0.29       100.81        3.86
# Off. Rebounds                 80.0          0.0        100.0         4.0
# TOTAL                         73.9         0.16       285.85        3.33
#
#                     Shooting 2pt Poss. Shooting 2pt FG% Shooting 2pt SQ  \
# PNR Ball Handler                     8             33.3            3.33
# PNR Screener                         6            100.0            2.33
# DHO Ball Handler                     4            100.0            3.75
# DHO Screener                         0              N/A             N/A
# ISOLATION                           19             57.1            2.29
# TRANSITION                           8             57.1            3.14
# Attacking Closeouts                  8             62.5            2.75
# Catch & Shoot                        0              N/A             N/A
# Off Ball Screens                     1            100.0             3.0
# Cutting                              8            100.0            3.86
# Off. Rebounds                        4            100.0             4.0
# TOTAL                               68             70.4            3.04
#
#                     Shooting 3pt Poss. Shooting 3pt FG% Shooting 3pt SQ  \
# PNR Ball Handler                     4             50.0            3.75
# PNR Screener                         1            100.0             5.0
# DHO Ball Handler                     1              0.0             4.0
# DHO Screener                         0              N/A             N/A
# ISOLATION                            4             50.0             3.5
# TRANSITION                           5              0.0            3.75
# Attacking Closeouts                  0              N/A             N/A
# Catch & Shoot                       14             35.7            3.93
# Off Ball Screens                     2              0.0             4.0
# Cutting                              0              N/A             N/A
# Off. Rebounds                        0              N/A             N/A
# TOTAL                               31             32.1            3.89
#
#                     Creation PPP % of Creation Poss. Creation TO Creation %  \
# PNR Ball Handler            1.61                26.6           0       43.7
# PNR Screener                 N/A                 0.0           0        0.0
# DHO Ball Handler             2.0                 2.9           0       16.7
# DHO Screener                 2.0                 2.9           0      100.0
# ISOLATION                   1.68                23.8           0       26.4
# TRANSITION                   1.1                31.1           0       43.9
# Attacking Closeouts          2.5                 5.7           0       19.2
# Catch & Shoot                N/A                 0.0           0        0.0
# Off Ball Screens             2.0                 2.9           0       25.0
# Cutting                      2.0                 2.9           0       10.1
# Off. Rebounds                2.0                 2.9           0       20.0
# TOTAL                       1.58                  35         0.0       26.1
#
#                     Creation FTR Creation TS% Creation SQ Creation 2pt Poss.  \
# PNR Ball Handler            0.38        84.46         3.5                  8
# PNR Screener                 0.0          N/A         N/A                  0
# DHO Ball Handler             0.0        100.0         2.0                  1
# DHO Screener                 0.0        100.0         3.0                  1
# ISOLATION                   0.43        94.09        3.43                  3
# TRANSITION                   0.2        57.47         4.0                  4
# Attacking Closeouts          0.0        125.0         4.0                  1
# Catch & Shoot                0.0          N/A         N/A                  0
# Off Ball Screens             0.0        100.0         5.0                  1
# Cutting                      0.0        100.0         4.0                  1
# Off. Rebounds                0.0        100.0         5.0                  1
# TOTAL                       0.25        263.5        3.72                 19
#
#                     Creation 2pt FG% Creation 2pt SQ Creation 3pt Poss.  \
# PNR Ball Handler                71.4            3.29                  1
# PNR Screener                     N/A             N/A                  0
# DHO Ball Handler               100.0             2.0                  0
# DHO Screener                   100.0             3.0                  0
# ISOLATION                      100.0             2.5                  5
# TRANSITION                     100.0            4.25                  6
# Attacking Closeouts            100.0             3.0                  1
# Catch & Shoot                    N/A             N/A                  0
# Off Ball Screens               100.0             5.0                  0
# Cutting                        100.0             4.0                  0
# Off. Rebounds                  100.0             5.0                  0
# TOTAL                           89.5            3.53                 13
#
#                     Creation 3pt FG% Creation 3pt SQ
# PNR Ball Handler               100.0            3.75
# PNR Screener                     N/A             5.0
# DHO Ball Handler                 N/A             4.0
# DHO Screener                     N/A             N/A
# ISOLATION                       60.0             3.5
# TRANSITION                      16.7            3.75
# Attacking Closeouts            100.0             N/A
# Catch & Shoot                    N/A            3.93
# Off Ball Screens                 N/A             4.0
# Cutting                          N/A             N/A
# Off. Rebounds                    N/A             N/A
# TOTAL                           46.2            3.89

# %%
data_PPP['Total SQ']['TOTAL']
# Out:
# '3.44'

# %%
shots = file['ovr_data']['shooting_locations']

off_PPP = data_PPP['Total PPP']['TOTAL']
off_total_SQ = data_PPP['Total SQ']['TOTAL']

# General plot parameters
mpl.rcParams['font.family'] = 'Avenir'
mpl.rcParams['font.size'] = 18
mpl.rcParams['axes.linewidth'] = 2
# Draw basketball court
nugg_off_fig = plt.figure(figsize=(5, 4.7))
nugg_off_ax = nugg_off_fig.add_axes([0, 0, 1, 1])
nugg_off_ax = create_court(nugg_off_ax, 'black')


for shot in shots:
    x = shot[0][0]
    y = shot[0][1] + 60
    res = shot[1]
    if res == 1:
        nugg_off_ax.plot(x,y, marker='o', color='#29c42e', markersize=8)
    if res == 0:
        nugg_off_ax.plot(x,y, marker='x', color='red', markersize=9)
    if res == 11: # Free Throws
        nugg_off_ax.plot(x,y, marker='^', color='#2393de', markersize=9)
        '''
    if res == 20: # Turnovers
        nugg_off_ax.plot(x,y, marker='D', color='grey', markersize=6)
        '''
    if res == 30: # And-1
        nugg_off_ax.plot(x,y, marker='^', color='#2393de', markersize=9)

print(f'NUGGETS OFFENSE SHOT CHART')
print('--------------------------')
print(f'Total PPP: {off_PPP} on {off_total_SQ} SQ')
        
plt.show()
# Out:
# NUGGETS OFFENSE SHOT CHART
# --------------------------
# Total PPP: 1.21 on 3.44 SQ

# %%
def_PPP = defense_file['ovr_data']['data']
def_PPP = pd.DataFrame(def_PPP).transpose()
def_PPP = defense_PPP(def_PPP)
def_PPP
# Out:
#                     Total PPP % of Poss. Total TO Total Creation % Total FTR  \
# PNR Ball Handler         0.45       13.8        0             72.7       0.0
# PNR Screener              1.2        6.2        0             40.0       0.0
# DHO Ball Handler          0.0        2.5        0             50.0       0.0
# DHO Screener              3.0        1.2        0            100.0       0.0
# ISOLATION                0.73       18.8        3              0.0       0.0
# TRANSITION               0.67       11.2        0             22.2       0.0
# Attacking Closeouts      0.67        7.5        0             33.3       0.0
# Catch & Shoot            1.11       23.8        0             26.3       0.0
# Off Ball Screens         1.25        5.0        1             25.0       0.0
# Cutting                   1.6        6.2        0             40.0       0.0
# Off. Rebounds            1.33        3.8        0              0.0       0.0
# TOTAL                    0.91         80      5.0             30.0       0.0
#
#                     Total TS% Total SQ Total 2pt FGA Total 2pt FG%  \
# PNR Ball Handler        22.73      3.0             8          12.5
# PNR Screener             60.0      3.2             3         100.0
# DHO Ball Handler          0.0      3.0             0           N/A
# DHO Screener            150.0      5.0             0           N/A
# ISOLATION               45.83      2.5            10          40.0
# TRANSITION              33.33     2.67             6          50.0
# Attacking Closeouts     33.33     3.17             6          33.3
# Catch & Shoot           55.26     3.68             0           N/A
# Off Ball Screens        83.33     2.33             2          50.0
# Cutting                  80.0      3.6             5          80.0
# Off. Rebounds           66.67      2.0             3          66.7
# TOTAL                   48.03     3.08            43          46.5
#
#                     Total 2pt SQ Total 3pt FGA Total 3pt FG% Total 3pt SQ  \
# PNR Ball Handler            3.12             3          33.3         2.67
# PNR Screener                3.67             2           0.0          2.5
# DHO Ball Handler             N/A             2           0.0          3.0
# DHO Screener                 N/A             1         100.0          5.0
# ISOLATION                    2.4             2          50.0          3.0
# TRANSITION                  2.33             3           0.0         3.33
# Attacking Closeouts         3.17             0           N/A          N/A
# Catch & Shoot                N/A            19          36.8         3.68
# Off Ball Screens             1.5             1         100.0          4.0
# Cutting                      3.6             0           N/A          N/A
# Off. Rebounds                2.0             0           N/A          N/A
# TOTAL                       2.79            33          33.3         3.45
#
#                     Shooting PPP % of Shooting Poss. Shooting TO  \
# PNR Ball Handler             0.0                 5.4           0
# PNR Screener                1.33                 5.4           0
# DHO Ball Handler             0.0                 1.8           0
# DHO Screener                 N/A                 0.0           0
# ISOLATION                   0.73                26.8           3
# TRANSITION                  0.57                12.5           0
# Attacking Closeouts          0.5                 7.1           0
# Catch & Shoot               1.07                25.0           0
# Off Ball Screens            1.67                 5.4           0
# Cutting                     1.33                 5.4           0
# Off. Rebounds               1.33                 5.4           0
# TOTAL                       0.88                  56        5.36
#
#                     Shooting Freq. Shooting FTR Shooting TS% Shooting SQ  \
# PNR Ball Handler              27.3          0.0          0.0         4.0
# PNR Screener                  60.0          0.0        66.67        2.67
# DHO Ball Handler              50.0          0.0          0.0         3.0
# DHO Screener                   0.0          0.0          N/A         N/A
# ISOLATION                    100.0          0.0        45.83         2.5
# TRANSITION                    77.8          0.0        28.57        2.71
# Attacking Closeouts           66.7          0.0         25.0         2.5
# Catch & Shoot                 73.7          0.0        53.57        3.57
# Off Ball Screens              75.0          0.0        83.33        2.33
# Cutting                       60.0          0.0        66.67        3.67
# Off. Rebounds                100.0          0.0        66.67         2.0
# TOTAL                         70.0          0.0        46.23        2.94
#
#                     Shooting 2pt Poss. Shooting 2pt FG% Shooting 2pt SQ  \
# PNR Ball Handler                     3              0.0             4.0
# PNR Screener                         2            100.0             3.0
# DHO Ball Handler                     0              N/A             N/A
# DHO Screener                         0              N/A             N/A
# ISOLATION                           13             40.0             2.4
# TRANSITION                           4             50.0            2.25
# Attacking Closeouts                  4             25.0             2.5
# Catch & Shoot                        0              N/A             N/A
# Off Ball Screens                     2             50.0             1.5
# Cutting                              3             66.7            3.67
# Off. Rebounds                        3             66.7             2.0
# TOTAL                               34             45.2            2.61
#
#                     Shooting 3pt Poss. Shooting 3pt FG% Shooting 3pt SQ  \
# PNR Ball Handler                     0              N/A             N/A
# PNR Screener                         1              0.0             2.0
# DHO Ball Handler                     1              0.0             3.0
# DHO Screener                         0              N/A             N/A
# ISOLATION                            2             50.0             3.0
# TRANSITION                           3              0.0            3.33
# Attacking Closeouts                  0              N/A             N/A
# Catch & Shoot                       14             35.7            3.57
# Off Ball Screens                     1            100.0             4.0
# Cutting                              0              N/A             N/A
# Off. Rebounds                        0              N/A             N/A
# TOTAL                               22             31.8            3.41
#
#                     Creation PPP % of Creation Poss. Creation TO Creation %  \
# PNR Ball Handler            0.62                33.3           0       72.7
# PNR Screener                 1.0                 8.3           0       40.0
# DHO Ball Handler             0.0                 4.2           0       50.0
# DHO Screener                 3.0                 4.2           0      100.0
# ISOLATION                    N/A                 0.0           0        0.0
# TRANSITION                   1.0                 8.3           0       22.2
# Attacking Closeouts          1.0                 8.3           0       33.3
# Catch & Shoot                1.2                20.8           0       26.3
# Off Ball Screens             0.0                 4.2           1       25.0
# Cutting                      2.0                 8.3           0       40.0
# Off. Rebounds                N/A                 0.0           0        0.0
# TOTAL                        1.0                  24        4.17       30.0
#
#                     Creation FTR Creation TS% Creation SQ Creation 2pt Poss.  \
# PNR Ball Handler             0.0        31.25        2.62                  5
# PNR Screener                 0.0         50.0         4.0                  1
# DHO Ball Handler             0.0          0.0         3.0                  0
# DHO Screener                 0.0        150.0         5.0                  0
# ISOLATION                    0.0          N/A         N/A                  0
# TRANSITION                   0.0         50.0         2.5                  2
# Attacking Closeouts          0.0         50.0         4.5                  2
# Catch & Shoot                0.0         60.0         4.0                  0
# Off Ball Screens             0.0          N/A         N/A                  1
# Cutting                      0.0        100.0         3.5                  2
# Off. Rebounds                0.0          N/A         N/A                  0
# TOTAL                        0.0        52.17        3.39                 13
#
#                     Creation 2pt FG% Creation 2pt SQ Creation 3pt Poss.  \
# PNR Ball Handler                20.0             2.6                  3
# PNR Screener                   100.0             5.0                  1
# DHO Ball Handler                 N/A             N/A                  1
# DHO Screener                     N/A             N/A                  1
# ISOLATION                        N/A             N/A                  0
# TRANSITION                      50.0             2.5                  0
# Attacking Closeouts             50.0             4.5                  0
# Catch & Shoot                    N/A             N/A                  5
# Off Ball Screens                 N/A             N/A                  0
# Cutting                        100.0             3.5                  0
# Off. Rebounds                    N/A             N/A                  0
# TOTAL                           50.0            3.25                 11
#
#                     Creation 3pt FG% Creation 3pt SQ
# PNR Ball Handler                33.3             N/A
# PNR Screener                     0.0             2.0
# DHO Ball Handler                 0.0             3.0
# DHO Screener                   100.0             N/A
# ISOLATION                        N/A             3.0
# TRANSITION                       N/A            3.33
# Attacking Closeouts              N/A             N/A
# Catch & Shoot                   40.0            3.57
# Off Ball Screens                 N/A             4.0
# Cutting                          N/A             N/A
# Off. Rebounds                    N/A             N/A
# TOTAL                           36.4            3.41

# %%
def_shots = defense_file['ovr_data']['shooting_locations']

# Draw basketball court
def_fig = plt.figure(figsize=(6, 5.64))
def_ax = def_fig.add_axes([0, 0, 1, 1])
def_ax = create_court(def_ax, 'black')

for shot in def_shots:
    x = shot[0][0]
    y = shot[0][1] + 60
    res = shot[1]
    if res == 1:
        def_ax.plot(x,y, marker='o', color='#29c42e', markersize=9)
    if res == 0:
        def_ax.plot(x,y, marker='x', color='red', markersize=10)
    if res == 11: # Free Throws
        def_ax.plot(x,y, marker='^', color='#2393de', markersize=10)
    if res == 20: # Turnovers
        def_ax.plot(x,y, marker='D', color='#f5c133', markersize=8)
    if res == 30: # And-1
        def_ax.plot(x,y, marker='P', color='#e00ddd', markersize=10)
    
plt.show()
