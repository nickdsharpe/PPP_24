# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap
import os
np.seterr(invalid='ignore')
from PPP import PPP
from defense_PPP import defense_PPP
from court import create_court
import matplotlib as mpl
import matplotlib.pyplot as plt
import json
import plotly.graph_objects as go
pd.options.display.max_columns = 999
from get_stats import get_stats

game = '11.14.23_Clippers'
total = '!season_totals'

# %%
total_folder = 'Nuggets/!season_totals'
game_dir = f'data/{game}/Nuggets/Offense'

players = []
for subdir, dirs, files in os.walk(game_dir):
    for file in files:
        if file[-5:] == '.json':
            player = file[:-5]
            players.append(player)

for player in players:
    if player[-10:] != 'checkpoint':
        get_stats('Nuggets', player, total, 'Offense', save=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8812\1672761921.py in <module>
#      11 for player in players:
#      12     if player[-10:] != 'checkpoint':
# ---> 13         get_stats('Nuggets', player, total, 'Offense', save=True)
#
# ~\OneDrive\Desktop\NBA\NBA_PPP_23_24\get_stats.py in get_stats(team, player, game, off_def, save)
#     146     # Save figure if save is True
#     147     if save:
# --> 148         nugg_off_fig.savefig(f'data/{game}/{team}/{off_def}/{player}.png', bbox_inches='tight', dpi=nugg_off_fig.dpi)
#     149
#     150     return PPP, rim_PPP, nugg_off_fig
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    3044                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3045
# -> 3046             self.canvas.print_figure(fname, **kwargs)
#    3047
#    3048     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2317                 # force the figure dpi to 72), so we need to set it again here.
#    2318                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319                     result = print_method(
#    2320                         filename,
#    2321                         facecolor=facecolor,
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     539         """
#     540         FigureCanvasAgg.draw(self)
# --> 541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673         pil_kwargs.setdefault("format", format)
#    1674         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675         image.save(fname, **pil_kwargs)
#    1676
#    1677
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2315                 fp = builtins.open(filename, "r+b")
#    2316             else:
# -> 2317                 fp = builtins.open(filename, "w+b")
#    2318
#    2319         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Season Total/Nuggets/Offense/Aaron Gordon.png'

# %%
off_PPP, off_rim_PPP, shot_chart = get_stats('Nuggets', 'Team', total, 'Offense')

# %%
off_PPP
# Out:
#                     Total PPP % of Poss. Total TO Total Creation % Total FTR  \
# PNR Ball Handler         1.09       17.5        0             31.8       0.0
# PNR Screener             0.87        5.5        1             14.5       0.4
# DHO Ball Handler         0.67        4.8        0             16.7       0.0
# DHO Screener              N/A        0.0        0                0       0.0
# ISOLATION                0.78       35.7        5             22.2      0.25
# TRANSITION               1.08        5.9        2             13.4       0.2
# Attacking Closeouts      1.75        3.2        0              0.0       0.0
# Catch & Shoot            0.56       12.7        0              0.0       0.0
# Off Ball Screens          1.6        4.0        0              0.0       0.0
# Cutting                  1.33        4.8        1             16.7       0.0
# Off. Rebounds             1.5        6.3        0             25.0       0.0
# TOTAL                    0.96        126      7.1             18.3      0.11
#
#                     Total TS% Total SQ Total 2pt FGA Total 2pt FG%  \
# PNR Ball Handler        54.55     3.09            15          60.0
# PNR Screener            51.02      2.8             3          66.7
# DHO Ball Handler        33.33     3.33             3          66.7
# DHO Screener              N/A        0             0           N/A
# ISOLATION               45.29     2.81            26          38.5
# TRANSITION              73.53      2.8             3          66.7
# Attacking Closeouts      87.5      4.5             2         100.0
# Catch & Shoot           28.12     3.69             0           N/A
# Off Ball Screens         80.0      4.0             2          50.0
# Cutting                  80.0      3.8             5          80.0
# Off. Rebounds            75.0      4.5             6         100.0
# TOTAL                   52.17     3.29            65          58.5
#
#                     Total 2pt SQ Total 3pt FGA Total 3pt FG% Total 3pt SQ  \
# PNR Ball Handler             2.6             7          28.6         4.14
# PNR Screener                1.67             2           0.0          4.5
# DHO Ball Handler             3.0             3           0.0         3.67
# DHO Screener                 N/A             0           N/A          N/A
# ISOLATION                   2.58            10          30.0          3.4
# TRANSITION                   2.0             2          50.0          4.0
# Attacking Closeouts          4.5             2          50.0          4.5
# Catch & Shoot                N/A            16          18.8         3.69
# Off Ball Screens             4.5             3          66.7         3.67
# Cutting                      3.8             0           N/A          N/A
# Off. Rebounds                4.5             2           0.0          4.5
# TOTAL                       2.92            47          25.5         3.81
#
#                     Shooting PPP % of Shooting Poss. Shooting TO  \
# PNR Ball Handler             1.2                14.6           0
# PNR Screener                1.02                 5.7           1
# DHO Ball Handler             0.8                 4.9           0
# DHO Screener                 N/A                 0.0           0
# ISOLATION                   0.69                33.9           5
# TRANSITION                  0.93                 6.3           2
# Attacking Closeouts         1.75                 3.9           0
# Catch & Shoot               0.56                15.5           0
# Off Ball Screens             1.6                 4.9           0
# Cutting                      1.2                 4.9           1
# Off. Rebounds                2.0                 5.8           0
# TOTAL                       0.97                 103        8.74
#
#                     Shooting Freq. Shooting FTR Shooting TS% Shooting SQ  \
# PNR Ball Handler              68.2          0.0         60.0         3.2
# PNR Screener                  85.5          0.5        61.48         2.5
# DHO Ball Handler              83.3          0.0         40.0         3.4
# DHO Screener                     0          0.0          N/A         N/A
# ISOLATION                     77.8         0.35         41.9         2.5
# TRANSITION                    86.6         0.25        67.57        2.25
# Attacking Closeouts          100.0          0.0         87.5         4.5
# Catch & Shoot                100.0          0.0        28.12        3.69
# Off Ball Screens             100.0          0.0         80.0         4.0
# Cutting                       83.3          0.0         75.0        3.75
# Off. Rebounds                 75.0          0.0        100.0         4.5
# TOTAL                         81.7         0.13        53.79        3.24
#
#                     Shooting 2pt Poss. Shooting 2pt FG% Shooting 2pt SQ  \
# PNR Ball Handler                    10             60.0             2.9
# PNR Screener                         4             66.7            1.67
# DHO Ball Handler                     3             66.7             3.0
# DHO Screener                         0              N/A             N/A
# ISOLATION                           33             36.0            2.48
# TRANSITION                           3             50.0             0.5
# Attacking Closeouts                  2            100.0             4.5
# Catch & Shoot                        0              N/A             N/A
# Off Ball Screens                     2             50.0             4.5
# Cutting                              5             75.0            3.75
# Off. Rebounds                        6            100.0             4.5
# TOTAL                               70             56.1            2.91
#
#                     Shooting 3pt Poss. Shooting 3pt FG% Shooting 3pt SQ  \
# PNR Ball Handler                     5             40.0             3.8
# PNR Screener                         1              0.0             5.0
# DHO Ball Handler                     2              0.0             4.0
# DHO Screener                         0              N/A             N/A
# ISOLATION                            1              0.0             3.0
# TRANSITION                           3             50.0             4.0
# Attacking Closeouts                  2             50.0             4.5
# Catch & Shoot                       16             18.8            3.69
# Off Ball Screens                     3             66.7            3.67
# Cutting                              0              N/A             N/A
# Off. Rebounds                        0              N/A             N/A
# TOTAL                               33             28.1            3.81
#
#                     Creation PPP % of Creation Poss. Creation TO Creation %  \
# PNR Ball Handler            0.86                30.4           0       31.8
# PNR Screener                 0.0                 4.3           0       14.5
# DHO Ball Handler             0.0                 4.3           0       16.7
# DHO Screener                 N/A                 0.0           0          0
# ISOLATION                    1.1                43.5           0       22.2
# TRANSITION                   2.0                 4.3           0       13.4
# Attacking Closeouts          N/A                 0.0           0        0.0
# Catch & Shoot                N/A                 0.0           0        0.0
# Off Ball Screens             N/A                 0.0           0        0.0
# Cutting                      2.0                 4.3           0       16.7
# Off. Rebounds                0.0                 8.7           0       25.0
# TOTAL                       0.91                  23         0.0       18.3
#
#                     Creation FTR Creation TS% Creation SQ Creation 2pt Poss.  \
# PNR Ball Handler             0.0        42.86        2.86                  5
# PNR Screener                 0.0          0.0         4.0                  0
# DHO Ball Handler             0.0          0.0         3.0                  0
# DHO Screener                 0.0          N/A         N/A                  0
# ISOLATION                    0.0         55.0         3.6                  1
# TRANSITION                   0.0        100.0         5.0                  1
# Attacking Closeouts          0.0          N/A         N/A                  0
# Catch & Shoot                0.0          N/A         N/A                  0
# Off Ball Screens             0.0          N/A         N/A                  0
# Cutting                      0.0        100.0         4.0                  1
# Off. Rebounds                0.0          0.0         4.5                  0
# TOTAL                        0.0        45.65        3.52                  8
#
#                     Creation 2pt FG% Creation 2pt SQ Creation 3pt Poss.  \
# PNR Ball Handler                60.0             2.0                  2
# PNR Screener                     N/A             N/A                  1
# DHO Ball Handler                 N/A             N/A                  1
# DHO Screener                     N/A             N/A                  0
# ISOLATION                      100.0             5.0                  9
# TRANSITION                     100.0             5.0                  0
# Attacking Closeouts              N/A             N/A                  0
# Catch & Shoot                    N/A             N/A                  0
# Off Ball Screens                 N/A             N/A                  0
# Cutting                        100.0             4.0                  0
# Off. Rebounds                    N/A             N/A                  2
# TOTAL                           75.0             3.0                 15
#
#                     Creation 3pt FG% Creation 3pt SQ
# PNR Ball Handler                 0.0             3.8
# PNR Screener                     0.0             5.0
# DHO Ball Handler                 0.0             4.0
# DHO Screener                     N/A             N/A
# ISOLATION                       33.3             3.0
# TRANSITION                       N/A             4.0
# Attacking Closeouts              N/A             4.5
# Catch & Shoot                    N/A            3.69
# Off Ball Screens                 N/A            3.67
# Cutting                          N/A             N/A
# Off. Rebounds                    0.0             N/A
# TOTAL                           20.0            3.81

# %%
path = f'data/!season_totals/Nuggets/Offense/Team.json'

with open (path, 'r') as o:
    offense_file = json.load(o)
    
shots_x = [shot[0][0] for shot in offense_file['ovr_data']['shooting_locations']]
shots_y = [shot[0][1] + 60 for shot in offense_file['ovr_data']['shooting_locations']]
shots_results = [shot[1] for shot in offense_file['ovr_data']['shooting_locations']]

shots_df = pd.DataFrame(columns=['LOC_X', 'LOC_Y', 'RESULT'])
shots_df['LOC_X'] = shots_x
shots_df['LOC_Y'] = shots_y
shots_df['RESULT'] = shots_results

cmap=plt.cm.gist_heat_r

joint_shot_chart = sns.jointplot(shots_df.LOC_X, shots_df.LOC_Y,
                                 kind='hex', space=0, color=cmap(.15), cmap=cmap)

joint_shot_chart.fig.set_size_inches(7,6.5)

ax = joint_shot_chart.ax_joint
create_court(ax, 'black')

# Get rid of axis labels and tick marks
ax.set_xlabel('')
ax.set_ylabel('')
ax.tick_params(labelbottom='off', labelleft='off')

#ax.set_title("Nuggets FGA's 2023-24", y=1.2, fontsize=18)
# Out:
# C:\Users\nickd\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
